# %%
# %matplotlib inline
import sys
if '..' not in sys.path:
    sys.path.append('..')
from utils import plot

# %%
plot(
    
    #'../runs/unet-limit100-sigmoid-lr-0.001/',
    '../runs/unet-limit100-sigmoid-lr-0.001-dice/',
    '../runs/unet-limit100-sigmoid-lr-0.0003-dice/',
    
    max_points=200,
    ymax=0.525,
    ymin=0.4,
    #xmax=10000,%%!
    )
