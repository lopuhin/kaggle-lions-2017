# %%
# %matplotlib inline
import sys
if '..' not in sys.path:
    sys.path.append('..')
from utils import plot

# %%
plot(
    #'../runs/unet-limit100/',
    #'../runs/unet-limit100-clean/',
    #'../runs/unet-limit100-clean-lr0.001/',
    #'../runs/unet-limit100-clean-lr0.004/',
    #'../runs/unet-limit100-clean-lr0.0004/',
    
    '../runs/unet-limit800-clean-lr0.0004/',
    '../runs/unet-limit500/',
    
    #'../runs/unet-limit100-nolw0.01-lr0.001/',
    #'../runs/unet-limit100-nolw0.01-lr0.0002/',
    #'../runs/unet-limit100-nolw0.1-lr0.0002/',
    max_points=200,
    ymax=0.008,
    ymin=0.002,
    #xmax=10000,
    )
