# %%
# %matplotlib inline
import sys
if '..' not in sys.path:
    sys.path.append('..')
from utils import plot

# %%
plot(
    
    #'../runs/clf-slimit300-sgdm-lr0.0001/',
    #'../runs/clf-slimit300-sgdm-lr0.00002/',
    #'../runs/clf-slimit300-sgdm-lr0.0001-flex/',
    
    
    #'../runs/unet-limit800-fold3-scale-0.9-1.6-oversample0.2/',
    #'../runs/unet-limit800-fold3-scale-0.8-1.6-oversample0.2-patch384/',
    
    '../runs/unet-stratified-scale-0.9-1.5-oversample0.3-fold3',
    #'../runs/unet-stratified-scale-0.8-1.6-oversample0.2/',
    #'../runs/unet-stratified-scale-0.8-1.6-oversample0.2-fold2',
    
    #'../runs/unet-stratified-scale-0.8-1.6-patch192-batch48/',
#'../runs/unet-stratified-scale-0.8-1.6-oversample0.3-patch192-batch48/',
    
    #'../runs/unet-limit800-fold3-scale-0.9-1.6-oversample0.5/',
    
#'../runs/unet-limit800-fold3-scale-0.8-1.25-oversample0.2/',  

    #'../runs/unet-limit800-fold3-scale-0.8-1.25-oversample0.2-patch384/',  
    
    #'../runs/unetwithhead-limit800-fold3-scale-0.8-1.25-oversample0.2-patch384/',  
    #'../runs/unetwithhead-limit800-fold3-scale-0.8-1.25-oversample0.2-patch384-2/',  
    
    max_points=100,
    ymax=0.03,
    #ymin=0.3,
    #xmax=1000,
    )
