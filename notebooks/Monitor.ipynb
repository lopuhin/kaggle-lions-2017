# %%
# %matplotlib inline
import sys
if '..' not in sys.path:
    sys.path.append('..')
from utils import plot

# %%
plot(
    '../runs/unet-limit100/',
    '../runs/unet-limit500/',
    
    #'../runs/unet-limit100-nolw0.01-lr0.001/',
    #'../runs/unet-limit100-nolw0.01-lr0.0002/',
    #'../runs/unet-limit100-nolw0.1-lr0.0002/',
    max_points=100,
    ymax=0.01,
    #xmax=2000,
    )
