# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
s1 = pd.read_csv('../unet-stratified-scale-0.8-1.6-oversample0.2-trained-more.csv', index_col=0)
s1[:3]
# Out:
#          adult_males  subadult_males  adult_females  juveniles  pups
# test_id
# 0                  1               1             13         26     0
# 1                  1               2              4          4     0
# 2                  1               1              1          1     0

# %%
s2 = pd.read_csv('../unet-stratified-scale-0.8-1.6-oversample0.2-ep13.csv', index_col=0)
s2[:3]
# Out:
#          adult_males  subadult_males  adult_females  juveniles  pups
# test_id
# 0                  1               1             10         25     1
# 1                  1               2              5          4     1
# 2                  1               1              2          2     1

# %%
s1.hist(bins=20, figsize=(12, 10));

# %%
s2.hist(bins=20, figsize=(12, 10));

# %%
(s2 - s1).hist(bins=20, figsize=(12, 10), log=True);

# %%
s1_old_af = s1.copy()
s1_old_af['adult_females'] = s2['adult_females']
s1_old_af.to_csv('../unet-stratified-scale-0.8-1.6-oversample0.2-trained-more-ep13-af.csv')

# %%
s3 = pd.read_csv('../unet-stratified-scale-0.8-1.6-oversample0.2-trained-more-regression-trained-on-ep13.csv',
                 index_col=0)
s3[:3]
# Out:
#          adult_males  subadult_males  adult_females  juveniles  pups
# test_id
# 0                  1               2             15         24     0
# 1                  2               2              4          4     1
# 2                  1               1              1          1     0

# %%
(s2 - s3).hist(bins=20, figsize=(12, 10), log=True);

# %%
(s1 - s3).hist(bins=20, figsize=(12, 10), log=True);
